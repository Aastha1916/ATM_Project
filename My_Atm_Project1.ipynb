# %% [markdown]
# MY ATM PROJECT
#
# The aim of ATM Simulation System project is to build a python based ATM(Automated Teller Machine) Simulation System.

# %%
class MY_ATM():
    def __init__(self, name, pin1, pin2=0, balance = 0, deposite_amount = 0, withdraw_amount = 0, transfer_amount = 0, checking_balance = 99999999):
        self.name = name
        self.pin1 = pin1
        self.pin2 = pin2
        self.deposite_amount = deposite_amount
        self.withdraw_amount  = withdraw_amount 
        self.transfer_amount = transfer_amount
        self.checking_balance = checking_balance
        self.balance = balance
        
    def check_pin(self,pin):
        if pin>=1000 and pin<=9999:
            return True
        else:
            print ("INVALID PIN !!\n")
            return False
        
    def Account_Details(self):
        print("------Account Details-----")
        print("Account holder: ",self.name)
        print("Account Pin: ",self.pin1)
        print("Account balance: ",self.balance)
        print("\n")
        
    def Check_Saving_Balance(self):
        print(f"Your Current Saving Balance is: {self.balance} $\n")
        
        
    def Deposit_Funds(self, deposite_amount):
        self.deposite_amount = deposite_amount
        self.balance = self.balance + self.deposite_amount
        print("AMOUNT SUCCESSFULLY DEPOSITED!!\n")
        atm.Check_Saving_Balance()
        
            
    def Withdraw_Funds(self, withdraw_amount):
        self.withdraw_amount = withdraw_amount
        if self.withdraw_amount <= self.balance:
            self.balance = self.balance - self.withdraw_amount
            print("WITHDRAWAL SUCCESSFULL!!\n")
            atm.Check_Saving_Balance()
        else:
            print("Not enough Balance to withdraw!!\n")
            atm.Check_Saving_Balance()
            print("Try with amount lesser than the current balance.\n")
            
            
    def Transfer_Funds(self, transfer_amount):
        if self.transfer_amount <= self.checking_balance:
            self.checking_balance -= self.transfer_amount
            self.balance = self.balance + self.transfer_amount
            atm.Check_Saving_Balance()
            print(f"Your Current Checking balance is: {self.checking_balance} $")
            
        else:
            print("Not enough Balance to transfer!!\n")
            print("Current Checking balance is: ",self.checking_balance)
            print("Try with amount lesser than this balance.\n")
            
        
    def Home_Section(self):
        while True:
            choice = int(input("Enter your Choice: \n1. Account Details\n2. Check Saving Balance\n3. Deposit Funds\n4. Withdraw Funds\n5. Transfer Funds\n6. Back\n6"))
            if choice == 1:
                atm.Account_Details()
            elif choice == 2:
                atm.Check_Saving_Balance()
            elif choice == 3:
                self.deposite_amount = int(input("Enter the amount you want to deposit: \n"))
                atm.Deposit_Funds(self.deposite_amount)
            elif choice == 4:
                self.withdraw_amount = int(input("Enter the amount you want to withdraw: \n"))
                atm.Withdraw_Funds(self.withdraw_amount)
            elif choice == 5:   
                self.transfer_amount = int(input("Enter the amount you want to transfer: \n"))
                atm.Transfer_Funds(self.transfer_amount)
            elif choice == 6:
                break
            else:
                print("INVALID CHOICE!!\n")
                
            
print("Welcome to My ATM !!")
name = input("Enter your Full Name: ")
pin1 = int(input("Enter your Pin: "))
atm = MY_ATM(name, pin1)
if atm.check_pin(pin1):
    pin2 = int(input("Enter your Pin again: "))
    atm.check_pin(pin2)
    if pin1 == pin2 :
        print("LOGGED IN SUCCESSFULLY!!!\n")
        while True:
            x = int(input("Enter you Choice: \n1.Home_Section\n2. Exit\n"))
            if x == 1:
                atm.Home_Section()
            elif x == 2:
                break
            else:
                print("INVALID OPTION!!\n")
        print("THANK YOU FOR CHOOSING US!!\n")
    else:
        print("Wrong Pin Entered!!\n")
# Out:
# Welcome to My ATM !!
# Enter your Full Name: Astha agarwal
# Enter your Pin: 1234
# Enter your Pin again: 1234
# LOGGED IN SUCCESSFULLY!!!
#
# Enter you Choice:
# 1.Home_Section
# 2. Exit
# 1
# Enter your Choice:
# 1. Account Details
# 2. Check Saving Balance
# 3. Deposit Funds
# 4. Withdraw Funds
# 5. Transfer Funds
# 6. Back
# 61
# ------Account Details-----
# Account holder:  Astha agarwal
# Account Pin:  1234
# Account balance:  0
#
#
# Enter your Choice:
# 1. Account Details
# 2. Check Saving Balance
# 3. Deposit Funds
# 4. Withdraw Funds
# 5. Transfer Funds
# 6. Back
# 62
# Your Current Saving Balance is: 0 INR
#
# Enter your Choice:
# 1. Account Details
# 2. Check Saving Balance
# 3. Deposit Funds
# 4. Withdraw Funds
# 5. Transfer Funds
# 6. Back
# 63
# Enter the amount you want to deposit:
# 2345
# AMOUNT SUCCESSFULLY DEPOSITED!!
#
# Your Current Saving Balance is: 2345 INR
#
# Enter your Choice:
# 1. Account Details
# 2. Check Saving Balance
# 3. Deposit Funds
# 4. Withdraw Funds
# 5. Transfer Funds
# 6. Back
# 64
# Enter the amount you want to withdraw:
# 123
# WITHDRAWAL SUCCESSFULL!!
#
# Your Current Saving Balance is: 2222 INR
#
# Enter your Choice:
# 1. Account Details
# 2. Check Saving Balance
# 3. Deposit Funds
# 4. Withdraw Funds
# 5. Transfer Funds
# 6. Back
# 65
# Enter the amount you want to transfer:
# 456
# Your Current Saving Balance is: 2678 INR
#
# Your Current Checking balance is: 99999543 INR
# Enter your Choice:
# 1. Account Details
# 2. Check Saving Balance
# 3. Deposit Funds
# 4. Withdraw Funds
# 5. Transfer Funds
# 6. Back
# 66
# Enter you Choice:
# 1.Home_Section
# 2. Exit
# 2
# THANK YOU FOR CHOOSING US!!
